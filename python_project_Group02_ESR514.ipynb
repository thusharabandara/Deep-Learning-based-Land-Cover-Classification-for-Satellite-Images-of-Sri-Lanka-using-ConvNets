# %% [markdown]
# <a href="https://colab.research.google.com/github/thusharabandara/Deep-Learning-based-Land-Cover-Classification-for-Satellite-Images-of-Sri-Lanka-using-ConvNets/blob/main/python_project_Group02_ESR514.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Downloading and Extracting the Dataset

# %%
# !wget 'https://github.com/thusharabandara/Deep-Learning-based-Land-Cover-Classification-for-Satellite-Images-of-Sri-Lanka-using-ConvNets/blob/4ae12428bae604358f400a6230a6ad067e9177db/Sat_dataset.zip'
# Out:
# --2022-09-07 09:55:40--  https://github.com/thusharabandara/Deep-Learning-based-Land-Cover-Classification-for-Satellite-Images-of-Sri-Lanka-using-ConvNets/blob/4ae12428bae604358f400a6230a6ad067e9177db/Sat_dataset.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-09-07 09:55:40 ERROR 404: Not Found.

# %% [markdown]
# Uploading the Dataset to Drive

# %%
# !unzip '/content/drive/MyDrive/Sat_dataset.zip'
# Out:
# Archive:  /content/drive/MyDrive/Sat_dataset.zip
#    creating: Sat_dataset/
#    creating: Sat_dataset/train_set/
#    creating: Sat_dataset/train_set/Urban/
#   inflating: Sat_dataset/train_set/Urban/Industrial_1.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_10.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_100.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_1000.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_101.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_102.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_103.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_104.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_105.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_106.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_107.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_108.jpg
#   inflating: Sat_dataset/train_set/Urban/Industrial_109.jpg
# ...

# %%
from PIL import Image
from IPython.display import display

# %%
im = Image.open('Sat_dataset/train_set/Water/SeaLake_9.jpg')

# %%
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64 at 0x7F0B15803710>

# %%
import numpy as np
image_arr = np.array(im)
image_arr.shape
image_arr
# Out:
# array([[[50, 78, 90],
#         [49, 79, 89],
#         [47, 80, 89],
#         ...,
#         [49, 87, 88],
#         [50, 86, 86],
#         [52, 88, 88]],
#
#        [[49, 79, 89],
#         [49, 79, 89],
#         [49, 79, 89],
#         ...,
#         [51, 86, 90],
#         [50, 85, 87],
#         [52, 87, 89]],
#
#        [[46, 79, 86],
#         [48, 78, 88],
#         [50, 78, 89],
#         ...,
#         [49, 82, 89],
#         [49, 82, 89],
#         [48, 83, 89]],
#
#        ...,
#
#        [[35, 57, 81],
#         [35, 57, 81],
#         [35, 56, 83],
#         ...,
#         [36, 58, 81],
#         [36, 58, 81],
#         [37, 59, 82]],
#
#        [[35, 57, 80],
#         [35, 57, 81],
#         [36, 56, 81],
#         ...,
#         [36, 58, 81],
#         [36, 58, 81],
#         [35, 57, 80]],
#
#        [[33, 58, 80],
#         [36, 56, 80],
#         [38, 56, 80],
#         ...,
#         [36, 58, 81],
#         [36, 58, 81],
#         [36, 58, 81]]], dtype=uint8)
